# %% [markdown]
# #<p style="color: red">_Tytuł projektu_</p>
# <p style="color: red">_Informacje o składzie grupy, terminie_</p>

# %% [markdown]
# ## Zbiór danych
# <p style="color: red">
# Informacje o zbiorze danych:
# <ul style="color: red">
# <li>opis (cel analizy),</li>
#   <li>skąd pochodzi (link), w jaki sposób załadowany</li>
#   <li>ilość danych (powinno być ok 50 000),</li>
#   <li>co oznaczają poszczególne kolumny i jakiego są typu</li>
# </ul>
# </p>

# %%
# opcjonalny kod (importy itp)
# ...

# %% [markdown]
# ## Analiza danych
# <p style="color: red">Analiza powinna prowadzona być z biznesowego punktu widzenia (Apache Spark traktowany jest tylko jako narzędzie ułatwiające rozwiązanie problemu).</p>

# %% [markdown]
# ### _Zadanie 1 (Import danych)_

# %% [markdown]
# #### Załadowanie danych do RDD
# <p style="color: red">Należy załadować zbiór danych do formatu RDD.</p>

# %%
# kod tutaj
# ...

# %% [markdown]
# #### Załadowanie danych do DataFrame (moduł Apache Spark SQL)
# <p style="color: red">Należy załadować zbiór danych do obiektu typu DataFrame (dowolny sposób). Proszę zwrócić uwagę na typy kolumn (schema). Pomocny [materiał](https://www.datacamp.com/community/tutorials/apache-spark-tutorial-machine-learning).</p>

# %%
# kod tutaj
# ...

# %%
# kod tutaj
# ....

# %% [markdown]
# ### _Zadanie 2 (Agregacja)_
# <p style="color: red">Sekcja opisująca 2 hipotezy które chcemy zwalidować za pomocą danych.
#
# Na podstawie ramki RDD i DSL DataFrame należy wykonać funkcje agregującą dane (dwie różne, nie trywialne) i opisać uzyskane wyniki.</p>

# %%
# agregacja danych z wykorzystaniem RDD
...

# %%
# agregacja danych z wykorzystaniem DSL Apache Spark SQL (DataFrame)
...

# %% [markdown]
# _<p style="color: red">Opis wyników uzyskanych w obu przypadkach</p>_

# %% [markdown]
# ### _Zadanie 3 (SQL)_
# <p style="color: red">Sekcja opisująca hipotezę którą chcemy zwalidować za pomocą danych (podobnie jak punkt wyżej). Obiekt DataFrame należy zapisać jako tabela w pamięci, wykonać zapytanie SQL w komórce i **zwizualizować wynik**.</p>

# %%
# kod tutaj
# ...

# %% [markdown]
# _<p style="color: red">Opis uzyskanych wyników</p>_

# %% [markdown]
# ### _Zadanie 4 (UDF)_
# <p style="color: red">Sekcja opisująca hipotezę którą chcemy zwalidować za pomocą danych. Należy utworzyć i wywołać własną funkcję UDF odpowiednio transformującą daną kolumnę, zaprezentować i opisać rezultat.</p>

# %%
# kod tutaj
# ...

# %% [markdown]
# _<p style="color: red">Opis uzyskanych wyników</p>_

# %% [markdown]
# ### _Zadanie 5 (MLlib)_
# <p style="color: red">Należy wywołać dowolny algorytm (klasyfikacja, regresja, rekomendacja) z pakietu MLlib w celu przeprowadzenia analizy predyktywnej na istniejących danych.</p>

# %%
# podział na zbiory testowe/treningowe
# deklaracja alogrytmu
# zadeklarowana siatka parametrów dla testowania krzyżowego
# obliczenie metryk dla zbioru testowego

# kod tutaj
# ...

# %% [markdown]
# _<p style="color: red">Opis uzyskanych wyników</p>_

# %% [markdown]
# ## Podsumowanie
# _<p style="color: red">Krótki wnioski z przeprowadzonej analizy.</p>_
#
# ### Dystrybucja notatnika
# 1. Wyeksportować notatnik do formatu `IPython Notebook`
# 2. Utworzyć archiwum ZIP zawierająca ww. notatnik i plik z użytymi danymi
# 3. Archiwum powinno być zawierać numery indeksów autorów projektu (np. `XXX_YYY.zip`)
# 4. Archiwum należy wysłać pod adres `norbert.kozlowski@pwr.edu.pl`.
